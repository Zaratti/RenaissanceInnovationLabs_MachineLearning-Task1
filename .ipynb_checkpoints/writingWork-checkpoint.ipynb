# %%
pip install transformers
# Out:
# ...
#
# ...

# %%
pip install tf-keras
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 217.9 kB/s eta 0:00:08
#     --------------------------------------- 0.0/1.7 MB 178.6 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/1.7 MB 233.8 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/1.7 MB 233.8 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/1.7 MB 217.9 kB/s eta 0:00:08
#    -- ------------------------------------- 0.1/1.7 MB 238.1 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/1.7 MB 226.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.7 MB 283.8 kB/s eta 0:00:06
# ...

# %%
pip install torch torchvision torchaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install easyocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH = 'renam.jpg'

# %%
reader = easyocr.Reader(['en'], gpu = False)
result = reader.readtext(IMAGE_PATH)
result

# %%
#from transformers import TrOCRProcessor, TFVisionEncoderDecoderModel
#from transformers import TFAutoModelForSeq2SeqLM, TrOCRConfig
from transformers import TFAutoModelForVision2Seq
from PIL import Image
import requests

# Load the correct model and configuration
#config = TrOCRConfig.from_pretrained('microsoft/trocr-base-stage1')
#model = TFAutoModelForSeq2SeqLM.from_pretrained('microsoft/trocr-base-stage1', config=config)


# load image from the IAM database
url = 'https://fki.tic.heia-fr.ch/static/img/a01-122-02-00.jpg'
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")

processor = TrOCRProcessor.from_pretrained('microsoft/trocr-base-handwritten')
#model = TFVisionEncoderDecoderModel.from_pretrained('microsoft/trocr-base-handwritten')
# Load TrOCR model and configuration
#model = TFAutoModelForSeq2SeqLM.from_pretrained('microsoft/trocr-base-stage1')
# Load the TrOCR model for vision-to-text tasks
model = TFAutoModelForVision2Seq.from_pretrained('microsoft/trocr-base')
pixel_values = processor(images=image, return_tensors="pt").pixel_values

generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/microsoft/trocr-base/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
